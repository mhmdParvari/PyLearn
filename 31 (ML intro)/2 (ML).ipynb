# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Normal Distribution

# %%
import numpy as np
x = np.random.normal(3, 1, 2000)
plt.hist(x, 50)
plt.show()

# %% [markdown]
# # Linear Regression

# %%
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))
print('R: ', r)
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# R:  -0.7585915243761551

# %% [markdown]
# # Polynomial Regression

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = np.poly1d(np.polyfit(x, y, 3))

myline = np.linspace(1, 22, 10)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# ### Finding out the R-squared

# %%
from sklearn.metrics import r2_score

print('R-squared: ', r2_score(y, mymodel(x)))
# Out:
# R-squared:  0.9432150416451025

# %% [markdown]
# # Multiple Regression

# %%
from sklearn import linear_model


df = pd.read_csv("data.csv")

X = df[['Weight', 'Volume']]
y = df['CO2']

regr = linear_model.LinearRegression()
regr.fit(X, y)

predictedCO2 = regr.predict([[2300, 1300]])

print(predictedCO2)
# Out:
# [107.2087328]
# c:\users\panam\appdata\local\programs\python\python38\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Train/Test

# %% [markdown]
# ### Train

# %%
x = np.random.normal(3, 1, 100)
y = np.random.normal(150, 40, 100) / x

train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

mymodel = np.poly1d(np.polyfit(train_x, train_y, 4))

myline = np.linspace(0, 6, 100)

plt.scatter(train_x, train_y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# ### Test

# %%
r2 = r2_score(test_y, mymodel(test_x))

print(r2)
# Out:
# 0.5030037441151816
