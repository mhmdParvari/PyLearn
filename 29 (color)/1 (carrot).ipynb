# %%
import matplotlib.pyplot as plt
import cv2 as cv

# %%
img = cv.imread('carrot.jpg')
b,g,r = cv.split(img)
# plt.imshow(g,'gray')

# %%
res = cv.merge((b,r,b))
cv.imwrite('brb.jpg', res)
plt.imshow(res)
