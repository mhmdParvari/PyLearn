# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import ImageFont, ImageDraw, Image
import cv2 as cv

# %%
logo = np.full((229,512,3), [87,83,82], np.uint8)
# logo=cv.cvtColor(logo, cv.COLOR_BGR2RGB)
logo[76:113, 76:113] = [242,80,34]
logo[116:153,76:113] = [0,164,239]
logo[76:113, 116:153] = [127,186,0]
logo[116:153, 116:153] = [255,185,0]

# cv.putText(logo, 'Microsoft', (174,134), cv.FONT_HERSHEY_SIMPLEX, 1.9, (255,255,255), 6)

font = ImageFont.truetype('seguisb.ttf', 61)
img_pil = Image.fromarray(logo)
draw = ImageDraw.Draw(img_pil)
draw.text((170,69), 'Microsoft', font= font, fill= (255,255,255,0))
logo = np.array(img_pil)

plt.imshow(logo)
